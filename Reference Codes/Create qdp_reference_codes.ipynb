-- %%
-- Create Quantexa Data Product individuals_all Schema metadata
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- metadata table
DROP TABLE IF EXISTS Metadata;

CREATE OR REPLACE TABLE Metadata (
    supplier STRING,
    dataProduct STRING,
    dataProductVersion STRING,
    schemaName STRING,
    schemaVersion STRING,
    schemaVariantName STRING,
    schemaVariantVersion STRING,
    instance STRING,
    instanceVersion STRING
);

INSERT INTO Metadata 
(
  supplier, 
  dataProduct,
  dataProductVersion,
  schemaName,
  schemaVersion,
  schemaVariantName,
  schemaVariantVersion,
  instance,
  instanceVersion
) 
VALUES (
  'quantexa.com',
  'com.quantexa.qdp.refcodes_all',
  '0.1',
  'qdp_refcodes_all',
  '0.1',
  'universal',
  '0.1',
  'not yet populated with data',
  ''
  );

-- %%
-- Create Quantexa Data Product Reference Code Schemas 

USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- tennant table
DROP TABLE IF EXISTS tennant;

CREATE OR REPLACE TABLE tennant ( 
	tennant_id BIGINT,
	tennant_name STRING,
	network_name STRING
 );

INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  0,
  'NO TENNANT',
  'NO NETWORK'
);

INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  1,
  'Banking Supply Chain Demo',
  'CS Post-It Out LTD - Trade & Working Capital'
);



INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  2,
  'FinCrime Demo',
  'Nine Gee LTD'
);



-- tennant table
DROP TABLE IF EXISTS record_source;

CREATE OR REPLACE TABLE record_source ( 
	record_source_id BIGINT,
	domain STRING,
	it_system STRING,
	network_name STRING
 );

INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  0,
  'NOT DEFINED',
  'NOT DEFINED',
  'NOT DEFINED'
);


INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  1,
  'com.quantexa.demo/banking',
  '',
  'CS Post-It Out LTD - Trade & Working Capital'
);


INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  2,
  'com.quantexa.demo/banking',
  '',
  'Nine Gee LTD'
);

-- %%
-- Create the "Before Quantexa Processing Demo" Tennant

USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  999,
  'Before Quantexa Processing Demo',
  'CS Post-It Out LTD - Trade & Working Capital'
);

INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  999,
  'com.quantexa.demo/banking',
  '',
  'CS Post-It Out LTD - Trade & Working Capital'
);

-- %%
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);
DELETE FROM tennant WHERE tennant_id = 100;
DELETE FROM record_source WHERE record_source_id = 100;
DELETE FROM tennant WHERE tennant_id = 101;
DELETE FROM record_source WHERE record_source_id = 101;

-- %%
-- Create the "Risk BCBS 239 Demo" Tennant

USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  100,
  'Risk 360 Demo',
  'Risk 360 Network'
);

INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  100,
  'com.quantexa.demo/banking/',
  '',
  'Risk 360 Network'
);


INSERT INTO tennant 
(
  tennant_id, 
  tennant_name,
  network_name
) 
VALUES (
  101,
  'Risk 360 Demo - Before Quantexa Processing',
  'Risk 360 Network'
);

INSERT INTO record_source 
(
  record_source_id, 
  domain,
  it_system,
  network_name
) 
VALUES (
  101,
  'com.quantexa.demo/banking/',
  '',
  'Risk 360 Network'
);


SELECT * from tennant;

-- %%
-- Create Quantexa Data Product concepts_all Schema
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- Domain table
DROP TABLE IF EXISTS Domain;

CREATE OR REPLACE TABLE Domain (
	domainId STRING NOT NULL,
	domainConceptId BIGINT NOT NULL,
	domainName STRING NOT NULL
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE Domain ADD CONSTRAINT pk_conceptAll_domain_domainId PRIMARY KEY (domainId);

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- Vocabulary table
DROP TABLE IF EXISTS Vocabulary;

CREATE OR REPLACE TABLE Vocabulary (
	vocabularyId STRING NOT NULL,
	vocabularyConceptId BIGINT NOT NULL,
	vocabularyName STRING NOT NULL,
	vocabularyReference STRING NOT NULL,
	vocabularyVersion STRING NOT NULL
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE Vocabulary ADD CONSTRAINT pk_conceptAll_vocabulary_vocabularyId PRIMARY KEY (vocabularyId);

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- ConceptClass table
DROP TABLE IF EXISTS ConceptClass;

CREATE OR REPLACE TABLE ConceptClass (
	conceptClassId STRING NOT NULL,
	conceptClassConceptId BIGINT NOT NULL,
	conceptClassName STRING NOT NULL
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE ConceptClass ADD CONSTRAINT pk_conceptAll_conceptClass_conceptClassId PRIMARY KEY (conceptClassId);

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- Concept table
DROP TABLE IF EXISTS Concept;

CREATE OR REPLACE TABLE Concept (
	conceptId BIGINT NOT NULL,
	domainId STRING NOT NULL,
	vocabularyId STRING NOT NULL,
	conceptClassId STRING NOT NULL,
	standardConcept STRING NOT NULL,
	conceptCode STRING NOT NULL,
  validStartDate DATE NOT NULL,
  validEndDate DATE NOT NULL,
  invalidReason STRING
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE Concept ADD CONSTRAINT pk_conceptAll_concept_conceptId PRIMARY KEY (conceptId);

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- ConceptSynonym table
DROP TABLE IF EXISTS ConceptSynonym;

CREATE OR REPLACE TABLE ConceptSynonym (
	conceptId BIGINT NOT NULL,
	languageConceptId BIGINT NOT NULL,
	conceptSynonymName STRING NOT NULL
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- Relationship table
DROP TABLE IF EXISTS Relationship;

CREATE OR REPLACE TABLE Relationship (
	relationshipId STRING NOT NULL,
	relationshipConceptId BIGINT NOT NULL,
  reverseRelationshipId STRING NOT NULL,
	relationshipName STRING NOT NULL,
  isHierarchical BOOLEAN NOT NULL DEFAULT FALSE,
  definesAncestry BOOLEAN NOT NULL DEFAULT FALSE
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE Relationship ADD CONSTRAINT pk_conceptAll_relationship_relationshipId PRIMARY KEY (relationshipId);

-- %%
-- Create Quantexa Data Product concepts_all Schema

-- Concpet Relationship table
DROP TABLE IF EXISTS ConceptRelationship;

CREATE OR REPLACE TABLE ConceptRelationship (
	conceptId1 BIGINT NOT NULL,
	conceptId2 BIGINT NOT NULL,
	relationshipId STRING NOT NULL,
  validStartDate DATE NOT NULL,
  validEndDate DATE NOT NULL,
  invalidReason STRING
) USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported');

ALTER TABLE ConceptRelationship ADD CONSTRAINT pk_conceptAll_ConceptRelationship_conceptId1_conceptID2 PRIMARY KEY (conceptId1, conceptId2);
