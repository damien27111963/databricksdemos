-- %%
-- Create Quantexa  Banking Demo raw locations
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- locations_raw
DROP TABLE IF EXISTS locations_raw;
CREATE TABLE IF NOT EXISTS locations_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/locations_raw.json';


--https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/locations_raw.json

-- %%
-- Create Quantexa Banking Demo raw individuals
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- individuals_raw
DROP TABLE IF EXISTS individuals_raw;
CREATE TABLE IF NOT EXISTS individuals_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/individual_raw.json';

-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/individual_raw.json

-- %%
-- Create Quantexa Banking Demo raw individual customers
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- individual_customers_raw
DROP TABLE IF EXISTS individual_customers_raw;
CREATE TABLE IF NOT EXISTS individual_customers_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/individual_customers_raw.json';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/individual_customers_raw.json

-- %%
-- Create Quantexa Banking Demo raw organisation
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- organisation_raw
DROP TABLE IF EXISTS organisations_raw;
CREATE TABLE IF NOT EXISTS organisations_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/organisation_raw.json';

-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/organisation_raw.json

-- %%
-- Create Quantexa Banking Demo raw organisation customers
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- organisation_customers_raw
DROP TABLE IF EXISTS organisation_customers_raw;
CREATE TABLE IF NOT EXISTS organisation_customers_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/organisation_customers_raw.json';

--- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/organisation_customers_raw.json

-- %%
-- Create Quantexa Banking Demo raw accounts
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- accounts_raw
DROP TABLE IF EXISTS accounts_raw;
CREATE TABLE IF NOT EXISTS accounts_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/accounts_raw.json';

-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/accounts_raw.json

-- %%
-- Create Quantexa Banking Demo raw account transactions
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

--account_transactions_raw
DROP TABLE IF EXISTS account_transactions_raw;
CREATE TABLE IF NOT EXISTS account_transactions_raw
USING CSV
OPTIONS (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/banking_fincrime_demo_raw/account_transactions_raw.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/banking_fincrime_demo_raw/account_transactions_raw.csv
