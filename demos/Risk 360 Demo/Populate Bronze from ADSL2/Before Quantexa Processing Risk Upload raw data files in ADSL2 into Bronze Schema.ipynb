# %%
# %sql

-- demo_banking_bronze.risk_360_demo_before_quantexa_processing

-- Create Quantexa Banking Demo raw location data
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);


-- risk_location_raw
DROP TABLE IF EXISTS risk_location_raw;
CREATE TABLE IF NOT EXISTS risk_location_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Location.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Location.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);


-- risk_individual_raw
DROP TABLE IF EXISTS risk_individual_raw;
CREATE TABLE IF NOT EXISTS risk_individual_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Individual.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Individual.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);


-- risk_organisation_raw
DROP TABLE IF EXISTS risk_organisation_raw;
CREATE TABLE IF NOT EXISTS risk_organisation_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Organisation.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Organisation.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- risk_account_raw
DROP TABLE IF EXISTS risk_account_raw;
CREATE TABLE IF NOT EXISTS risk_account_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Accounts.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Accounts.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);


-- risk_organisation_individual_bridge_raw
DROP TABLE IF EXISTS risk_organisation_individual_bridge_raw;
CREATE TABLE IF NOT EXISTS risk_organisation_individual_bridge_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Organisation_Individuals_Bridge.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/Dummy_Data_Organisation_Individuals_Bridge.csv

# %%
# %sql
-- Create Quantexa Banking Demo account_transactions_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);


-- risk_organisation_individual_bridge_raw
DROP TABLE IF EXISTS risk_account_transactions_raw;
CREATE TABLE IF NOT EXISTS risk_account_transactions_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/account_transactions_raw.csv';



-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_360_demo/before_quantexa_processing/account_transactions_raw.csv
