-- %%
--SELECT version();

CREATE SCHEMA IF NOT EXISTS qdp_links_all;

SET search_path TO qdp_links_all;



-- metadata table
DROP TABLE IF EXISTS metadata;



CREATE TABLE metadata ( 
	supplier VARCHAR,
	data_product VARCHAR,
	data_product_version VARCHAR,
	schema_name VARCHAR,
	schema_version VARCHAR,
	schema_variant_name VARCHAR,
	schema_variant_version VARCHAR,
	instance VARCHAR,
	instance_version VARCHAR
 );




INSERT INTO metadata 
(
  supplier, 
  data_product,
  data_product_version,
  schema_name,
  schema_version,
  schema_variant_name,
  schema_variant_version,
  instance,
  instance_version
) 
VALUES (
  'quantexa.com',
  'com.quantexa.qdp.links_all',
  '0.1',
  'links_all.data_vault',
  '0.1',
  'base',
  '0.1',
  'not yet populated with data',
  ''
);





-- Organisation Address History
DROP TABLE IF EXISTS link_organisation_address_history;


CREATE TABLE link_organisation_address_history ( 
	organisation_address_history_id BIGINT NOT NULL GENERATED  ALWAYS AS IDENTITY (MINVALUE 0 START WITH 0 INCREMENT BY 1),
	tennant_id BIGINT NOT NULL DEFAULT 0,
	organisation_id BIGINT NOT NULL,
	organisation_entity_id VARCHAR NOT NULL,
	address_id BIGINT NOT NULL,
	address_entity_id VARCHAR NOT NULL,
	is_primary_address BOOLEAN NOT NULL DEFAULT FALSE,
	use_code VARCHAR,
	use_concept_id BIGINT,
	use_raw_code VARCHAR,
	use_raw_concept_id BIGINT,
	period_start TIMESTAMP,
	period_end TIMESTAMP,
	CONSTRAINT pk_organisationall_organisationaddresshistory_organisationaddresshistoryid PRIMARY KEY ( organisation_address_history_id )
 );


COMMENT ON COLUMN link_organisation_address_history.organisation_address_history_id IS 'Organisation Address History Identity';


/**
ALTER TABLE link_organisation_address_history ADD CONSTRAINT fk_qdplinks_organisationaddresshistory_huborganisation_organisationid FOREIGN KEY (organisation_id) REFERENCES qdp_organisations_all.hub_organisation(organisation_id);

ALTER TABLE link_organisation_address_history ADD CONSTRAINT fk_qdplinks_organisationaddresshistory_hubaddress_addressid FOREIGN KEY (address_id) REFERENCES qdp_locations_all.hub_address(address_id);
**/



-- Individual Address History
DROP TABLE IF EXISTS link_individual_address_history;

CREATE TABLE link_individual_address_history ( 
	individual_address_history_id BIGINT NOT NULL GENERATED  ALWAYS AS IDENTITY (MINVALUE 0 START WITH 0 INCREMENT BY 1),
	tennant_id BIGINT NOT NULL DEFAULT 0,
	individual_id BIGINT NOT NULL,
	individual_entity_id VARCHAR NOT NULL,
	address_id BIGINT NOT NULL,
	address_entity_id VARCHAR NOT NULL,
	is_primary_address BOOLEAN NOT NULL DEFAULT FALSE,
	use_code VARCHAR,
	use_concept_id BIGINT,
	use_raw_code VARCHAR,
	use_raw_concept_id BIGINT,
	period_start TIMESTAMP,
	period_end TIMESTAMP,
	CONSTRAINT pk_individualall_individualaddresshistory_individualaddresshistoryid PRIMARY KEY ( individual_address_history_id )
 );

COMMENT ON COLUMN link_individual_address_history.individual_address_history_id IS 'Individual Address History Identity';

ALTER TABLE link_individual_address_history ADD CONSTRAINT fk_qdplinks_individualaddresshistory_hubindividual_individualid FOREIGN KEY (individual_id) REFERENCES qdp_individuals_all.hub_individual(individual_id);


-- ALTER TABLE link_individual_address_history ADD CONSTRAINT fk_qdplinks_individualaddresshistory_hubaddress_addressid FOREIGN KEY (address_id) REFERENCES qdp_locations_all.hub_address(address_id);
