# %%
# %sql
-- Create Quantexa  Banking Demo raw locations
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- qcdmBusinessAccountTransactions_raw
DROP TABLE IF EXISTS qcdmBusinessAccountTransactions_raw;
CREATE TABLE IF NOT EXISTS qcdmBusinessAccountTransactions_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/qcdmBusinessAccountTransactions.json';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/qcdmBusinessAccountTransactions.json

--https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/qcdmBusinessAccountTransactions.json

# %%
# %sql
-- Create Quantexa Banking Demo raw qcdmIndividualAccountTransactions
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- qcdmIndividualAccountTransactions_raw
DROP TABLE IF EXISTS qcdmIndividualAccountTransactions_raw;
CREATE TABLE IF NOT EXISTS qcdmIndividualAccountTransactions_raw
USING JSON
OPTIONS (multiline = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/qcdmIndividualAccountTransactions.json';

-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/qcdmIndividualAccountTransactions.json

# %%
# %sql

-- Create Quantexa Banking Demo business_customers_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- business_customers_raw
DROP TABLE IF EXISTS business_customers_raw;
CREATE TABLE IF NOT EXISTS business_customers_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_customers_raw.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_customers_raw.csv

# %%
# %sql
-- Create Quantexa Banking Demo business_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- business_accounts_raw
DROP TABLE IF EXISTS business_accounts_raw;
CREATE TABLE IF NOT EXISTS business_accounts_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_accounts_raw.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_accounts_raw.csv

# %%
# %sql
-- Create Quantexa Banking Demo business_account_transactions_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- business_account_transactions_raw
DROP TABLE IF EXISTS business_account_transactions_raw;
CREATE TABLE IF NOT EXISTS business_account_transactions_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_account_transactions_raw.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/business_account_transactions_raw.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_customers_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- individual_customers_raw
DROP TABLE IF EXISTS individual_customers_raw;
CREATE TABLE IF NOT EXISTS individual_customers_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/individual_customers_raw.csv';


--https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/individual_customers_raw.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG IDENTIFIER(:p_catalog_name);
USE SCHEMA IDENTIFIER(:p_schema_name);

-- individual_accounts_raw
DROP TABLE IF EXISTS individual_accounts_raw;
CREATE TABLE IF NOT EXISTS individual_accounts_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/individual_accounts_raw.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/before_and_after_quantexa_processing_demo/individual_accounts_raw.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG demo_banking_bronze;
USE SCHEMA risk_bcbs239_demo;

-- risk_location_raw
DROP TABLE IF EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_location_raw;
CREATE TABLE IF NOT EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_location_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Location.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Location.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG demo_banking_bronze;
USE SCHEMA risk_bcbs239_demo;

-- risk_individual_raw
DROP TABLE IF EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_individual_raw;
CREATE TABLE IF NOT EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_individual_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Individual.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Individual.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG demo_banking_bronze;
USE SCHEMA risk_bcbs239_demo;

-- risk_organisation_raw
DROP TABLE IF EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_organisation_raw;
CREATE TABLE IF NOT EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_organisation_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Organisation.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Organisation.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG demo_banking_bronze;
USE SCHEMA risk_bcbs239_demo;

-- risk_account_raw
DROP TABLE IF EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_account_raw;
CREATE TABLE IF NOT EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_account_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Accounts.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Accounts.csv

# %%
# %sql
-- Create Quantexa Banking Demo individual_accounts_raw
USE CATALOG demo_banking_bronze;
USE SCHEMA risk_bcbs239_demo;

-- risk_organisation_individual_bridge_raw
DROP TABLE IF EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_organisation_individual_bridge_raw;
CREATE TABLE IF NOT EXISTS demo_banking_bronze.risk_bcbs239_demo.risk_organisation_individual_bridge_raw
USING CSV
OPTIONS  (header = 'true', inferSchema = 'true')
LOCATION 'abfss://data@sand1dbdemodev2data.dfs.core.windows.net/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Organisation_Individuals_Bridge.csv';


-- https://sand1dbdemodev2data.blob.core.windows.net/data/data/bronze/demo/banking/risk_bcbs239_demo/Dummy_Data_Organisation_Individuals_Bridge.csv
